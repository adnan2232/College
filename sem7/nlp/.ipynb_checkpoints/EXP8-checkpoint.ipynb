# %%
from spacy import displacy
from collections import Counter
from nltk.corpus import gutenberg
from nltk import pos_tag
from pprint import pprint
import spacy
import nltk
import essential_generators

# %%
enr = spacy.load("en_core_web_sm")
text = essential_generators.DocumentGenerator().paragraph()
text
# Out:
# "Address uniqueness. genus. unstable or. Of empirical stock decline and contributing to the. Related behavior currently explored by such factors. Ardennes uplands of sandy roads stretching across the western world since the formation of. Temperatures falling practical bearings you conceive the. Constant with constitution, ruled with emergency powers and have only one of the. Beam. except states, killing an estimated 5.9 magnitude, was in. Metropolitan atlanta are licensed and regulated. Utility. frequency: greening of the constraint logic program and. Researching specific complex bending magnet arrangement which produces a beam path of the flemish. Could result species, but is one of the largest natural freshwater. Its relative is shown to lead to cataplexy, and unpleasant laughter spells.. Almost exactly after aristotle's book, his pupil democritus.. Some influence measurements, from. Lasted for and other christian."

# %%
doc = enr(text)
pprint([(x.text,x.label_) for x in doc.ents])
# Out:
# [('only one', 'CARDINAL'),
#  ('an estimated 5.9', 'CARDINAL'),
#  ('Metropolitan', 'GPE'),
#  ('atlanta', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('christian', 'NORP')]

# %%
pprint([(x,x.ent_iob_,x.ent_type_) for x in doc])
# Out:
# [(Address, 'O', ''),
#  (uniqueness, 'O', ''),
#  (., 'O', ''),
#  (genus, 'O', ''),
#  (., 'O', ''),
#  (unstable, 'O', ''),
#  (or, 'O', ''),
#  (., 'O', ''),
#  (Of, 'O', ''),
#  (empirical, 'O', ''),
#  (stock, 'O', ''),
#  (decline, 'O', ''),
#  (and, 'O', ''),
#  (contributing, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (., 'O', ''),
#  (Related, 'O', ''),
#  (behavior, 'O', ''),
#  (currently, 'O', ''),
#  (explored, 'O', ''),
#  (by, 'O', ''),
#  (such, 'O', ''),
#  (factors, 'O', ''),
#  (., 'O', ''),
#  (Ardennes, 'O', ''),
#  (uplands, 'O', ''),
#  (of, 'O', ''),
#  (sandy, 'O', ''),
#  (roads, 'O', ''),
#  (stretching, 'O', ''),
#  (across, 'O', ''),
#  (the, 'O', ''),
#  (western, 'O', ''),
#  (world, 'O', ''),
#  (since, 'O', ''),
#  (the, 'O', ''),
#  (formation, 'O', ''),
#  (of, 'O', ''),
#  (., 'O', ''),
#  (Temperatures, 'O', ''),
#  (falling, 'O', ''),
#  (practical, 'O', ''),
#  (bearings, 'O', ''),
#  (you, 'O', ''),
#  (conceive, 'O', ''),
#  (the, 'O', ''),
#  (., 'O', ''),
#  (Constant, 'O', ''),
#  (with, 'O', ''),
#  (constitution, 'O', ''),
#  (,, 'O', ''),
#  (ruled, 'O', ''),
#  (with, 'O', ''),
#  (emergency, 'O', ''),
#  (powers, 'O', ''),
#  (and, 'O', ''),
#  (have, 'O', ''),
#  (only, 'B', 'CARDINAL'),
#  (one, 'I', 'CARDINAL'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (., 'O', ''),
#  (Beam, 'O', ''),
#  (., 'O', ''),
#  (except, 'O', ''),
#  (states, 'O', ''),
#  (,, 'O', ''),
#  (killing, 'O', ''),
#  (an, 'B', 'CARDINAL'),
#  (estimated, 'I', 'CARDINAL'),
#  (5.9, 'I', 'CARDINAL'),
#  (magnitude, 'O', ''),
#  (,, 'O', ''),
#  (was, 'O', ''),
#  (in, 'O', ''),
#  (., 'O', ''),
#  (Metropolitan, 'B', 'GPE'),
#  (atlanta, 'B', 'GPE'),
#  (are, 'O', ''),
#  (licensed, 'O', ''),
#  (and, 'O', ''),
#  (regulated, 'O', ''),
#  (., 'O', ''),
#  (Utility, 'O', ''),
#  (., 'O', ''),
#  (frequency, 'O', ''),
#  (:, 'O', ''),
#  (greening, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (constraint, 'O', ''),
#  (logic, 'O', ''),
#  (program, 'O', ''),
#  (and, 'O', ''),
#  (., 'O', ''),
#  (Researching, 'O', ''),
#  (specific, 'O', ''),
#  (complex, 'O', ''),
#  (bending, 'O', ''),
#  (magnet, 'O', ''),
#  (arrangement, 'O', ''),
#  (which, 'O', ''),
#  (produces, 'O', ''),
#  (a, 'O', ''),
#  (beam, 'O', ''),
#  (path, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (flemish, 'O', ''),
#  (., 'O', ''),
#  (Could, 'O', ''),
#  (result, 'O', ''),
#  (species, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (is, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (largest, 'O', ''),
#  (natural, 'O', ''),
#  (freshwater, 'O', ''),
#  (., 'O', ''),
#  (Its, 'O', ''),
#  (relative, 'O', ''),
#  (is, 'O', ''),
#  (shown, 'O', ''),
#  (to, 'O', ''),
#  (lead, 'O', ''),
#  (to, 'O', ''),
#  (cataplexy, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (unpleasant, 'O', ''),
#  (laughter, 'O', ''),
#  (spells, 'O', ''),
#  (.., 'O', ''),
#  (Almost, 'O', ''),
#  (exactly, 'O', ''),
#  (after, 'O', ''),
#  (aristotle, 'O', ''),
#  ('s, 'O', ''),
#  (book, 'O', ''),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (pupil, 'O', ''),
#  (democritus, 'O', ''),
#  (.., 'O', ''),
#  (Some, 'O', ''),
#  (influence, 'O', ''),
#  (measurements, 'O', ''),
#  (,, 'O', ''),
#  (from, 'O', ''),
#  (., 'O', ''),
#  (Lasted, 'O', ''),
#  (for, 'O', ''),
#  (and, 'O', ''),
#  (other, 'O', ''),
#  (christian, 'B', 'NORP'),
#  (., 'O', '')]

# %%
displacy.render(doc,jupyter=True,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Address uniqueness. genus. unstable or. Of empirical stock decline and contributing to the. Related behavior currently explored by such factors. Ardennes uplands of sandy roads stretching across the western world since the formation of. Temperatures falling practical bearings you conceive the. Constant with constitution, ruled with emergency powers and have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the. Beam. except states, killing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an estimated 5.9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  magnitude, was in.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metropolitan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     atlanta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  are licensed and regulated. Utility. frequency: greening of the constraint logic program and. Researching specific complex bending magnet arrangement which produces a beam path of the flemish. Could result species, but is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the largest natural freshwater. Its relative is shown to lead to cataplexy, and unpleasant laughter spells.. Almost exactly after aristotle's book, his pupil democritus.. Some influence measurements, from. Lasted for and other
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# .</div></span>
